# %%
#import library sklearn
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
#load iris dataset from sklearn library, iris dataset have 150 data
iris = datasets.load_iris()

#separate attribute and label in dataset
x = iris.data
y = iris.target

# %%
"""split train dataset and test dataset
with x is train dataset and y is test dataset.
split 20% for test dataset
"""
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
#check length from x_test, it's show 30 from dataset
len(x_test)
# Out:
# 30
